# %%
import yfinance as yf
# import numpy as np
import sys
import asyncio
import pandas as pd
# import glob
import requests
import os
import json
import csv

f = open('companies.json',)
s = open('companies1.json',)
x = "http://localhost:8081/getCompanyData"
y = "http://localhost:8081/getAnalysis"

data = json.load(f)
data1 = json.load(s)
cmp = []
value = []
df = {}
for i in data['allCompanies']:
    cal = []
    url = x+i
    response = requests.get(url)
    d = response.text
    parsed = json.loads(d)
    ans = 0
    cmpName = parsed['name']
    for l in parsed['data']:
        t = l["period"]
        lvl = l["level"]
        ind = l["indication"]
        if(t == "MACD(12,26,9)"):
            if(lvl > '0'):
                cal.append("Bullish")
            else:
                cal.append("Bearish")

        if(t == "RSI(14)"):
            if(lvl > '70'):
                cal.append("Bearish")
            elif(lvl < '30'):
                cal.append("Bullish")
            else:
                cal.append("Neutral")


        if(t == "Stochastic(20,3)"):
            if(lvl > '80'):
                cal.append("Bearish")
            else:
                cal.append("Bullish")

        if(t == "ROC(20)"):
             if(lvl > '0'):
                cal.append("Bullish")
             else:
                cal.append("Bearish")


        if(t == "CCI(20)"):
            if(lvl > '100'):
                cal.append("Bearish")
            elif(lvl > '100'):
                cal.append("Bullish")
            else:
                cal.append("Bearish")


        if(t == "RSC (6 months)"):
            if(ind =="Outperformer"):
                cal.append("Bullish")
            else:
                cal.append("Bearish")


        if(t == "ADX(14)"):
            if(lvl > "25"):
                cal.append("Bullish")
            else:
                cal.append("Bearish")

    for i in cal:
        if(i == "Bullish"):
            ans+=1
    cmpName = cmpName + ".NS"
    df[cmpName] = ans

sort_orders = sorted(df.items(), key=lambda x: x[1], reverse=True)

for i in sort_orders:
	print(i[0], i[1])


f.close()
s.close()
# Out:
# TITAN.NS 5
# TRENT.NS 5
# ADANIGREEN.NS 5
# ADANITRANS.NS 5
# TATAMOTORS.NS 4
# IDEA.NS 4
# SBIN.NS 4
# TECHM.NS 4
# TATASTEEL.NS 4
# TATACONSUM.NS 4
# TATACOMM.NS 4
# TVSMOTOR.NS 4
# AXISBANK.NS 4
# DMART.NS 4
# AMBUJACEM.NS 4
# ADANIENT.NS 4
# YESBANK.NS 3
# FRETAIL.NS 3
# ASIANPAINT.NS 3
# TCS.NS 2
# TORNTPHARM.NS 2
# AUROPHARMA.NS 2
# RELIANCE.NS 1

# %%
tickers = []

# %%
from GoogleNews import GoogleNews
from newspaper import Article
import pandas as pd

# %%
for t in sort_orders[:6]:
    tickers.append((t[0].split('.'))[0].lower())

# %%
tickers
# Out:
# ['titan', 'trent', 'adanigreen', 'adanitrans', 'tatamotors', 'idea']

# %%
import time

# %%
headline=[]


for tick in tickers:
    googlenews=GoogleNews(start='11/01/2020',end='11/25/2020')
    googlenews.search(tick)
    
    for i in range(2,4):
        googlenews.getpage(i)
        #time.sleep(5)
        result=googlenews.result(sort=False)
        #time.sleep(5)
        df=pd.DataFrame(result)
        #print(df)
        
        df.replace("[^a-zA-Z]"," ",regex=True, inplace=True)
        df['title'] = df['title'].str.lower()
        headline.append(' '.join(str(x) for x in df['title']))
        #list1= [i for i in range(7)]
        #new_Index=[str(i) for i in list1]
        #df.head()
        #df.columns= new_Index
        #data.head(5)
        #df['0'] = df['0'].str.lower()
        
        #time.sleep(5)
        #print(df['title'])
        #df = df.loc[0:24]
        print(df)
    
   # DF_lis.append(df)
# Out:
#                                                 title                 media  \
# 0   titan comes up with business update for festiv...              Livemint
# 1   titan s jewellery business posts     growth in...        BloombergQuint
# 2   titan company share price hits    week high af...      Moneycontrol com
# 3   titan company gains as jewellery business reco...           NDTV Profit
# 4   rip  titan  pennsylvania police mourn k   offi...             USA TODAY
# 5   titan pharmaceuticals reports third quarter   ...            PRNewswire
# 6   titan  tbz  trading strategies for jewellery r...     Business Standard
# 7   titan international  inc  reports third quarte...            PRNewswire
# 8   taneira by titan launches its flagship store i...         retail growth
# 9   weird molecule found in titan s atmosphere hin...             New Atlas
# 10  normalcy returning  watches   eyewear business...              CNBCTV
# 11  titan   s atmosphere has all the ingredients f...        Universe Today
# 12  attack on titan    things we know about season...                   CBR
# 13   funding alert  healthtech startup prescribe r...         YourStory com
# 14  nissan reportedly tapping ev startup hercules ...              Autoblog
# 15      linq   titan school solutions announce merger
# 16  titan company launches first international tan...  United News of India
# 17  attack on titan season    final season likely ...          Devdiscourse
# 18  titan cement group and flsmidth announce new s...          World Cement
# 19  attack on titan s final battle begins amid glo...                   CBR
#
#            date                   datetime  \
# 0      week ago 2020-11-19 23:11:34.558399
# 1      week ago 2020-11-19 23:11:34.560393
# 2      week ago 2020-11-19 23:11:34.562388
# 3      days ago 2020-11-20 23:11:34.564383
# 4      days ago 2020-11-23 23:11:34.566378
# 5      week ago 2020-11-19 23:11:34.568372
# 6     weeks ago 2020-11-12 23:11:34.570367
# 7     weeks ago 2020-11-05 23:11:34.572361
# 8     weeks ago 2020-11-05 23:11:34.574356
# 9     weeks ago 2020-11-05 23:11:34.577349
# 10     week ago 2020-11-19 23:11:39.569889
# 11    weeks ago 2020-11-05 23:11:39.572881
# 12     days ago 2020-11-21 23:11:39.574875
# 13     week ago 2020-11-19 23:11:39.576871
# 14     days ago 2020-11-20 23:11:39.578864
# 15    weeks ago 2020-11-12 23:11:39.580858
# 16    weeks ago 2020-11-05 23:11:39.582854
# 17     days ago 2020-11-24 23:11:39.584850
# 18     days ago 2020-11-24 23:11:39.586844
# 19    weeks ago 2020-11-12 23:11:39.588837
#
#                                                  desc  \
# 0   Titan shares rose    to        in noon trade t...
# 1   Shares of Titan Co  jumped to the highest in n...
# 2   Its eyewear business has also witnessed good t...
# 3   Shares of jewellery and watch retailer   Titan...
# 4   K  Officer Titan died  honorably in the line o...
# 5   Dr  Marc Rubin  Titan s Executive Chairman  to...
# 6   At       am  shares of Titan Company were trad...
# 7    Titan s third quarter financial results and o...
# 8   Taneira by Titan launches its flagship store i...
# 9   Titan is one of the most fascinating place in ...
# 10  S Subramaniam  CFO of Titan said sales were re...
# 11  In their study  which appeared in Astronomy   ...
# 12  The release dates of Attack On Titan seasons h...
# 13  Bipin Shah  Partner at Titan Capital  said    ...
# 14  An electric Titan would join the thundering he...
# 15  LINQ   TITAN School Solutions Announce Merger ...
# 16  Kolkata  Nov     UNI  Titan Company announced ...
# 17  Attack on Titan Season    Final season likely ...
# 18  Sustainability  digitalisation and productivit...
# 19  In morbidly appropriate fashion for such a tum...
#
#                                                  link  \
# 0   https   www livemint com market stock market n...
# 1   https   www bloombergquint com markets titans ...
# 2   https   www moneycontrol com news business sto...
# 3   https   www ndtv com business share market upd...
# 4   https   www usatoday com story news nation    ...
# 5   https   www prnewswire com news releases titan...
# 6   https   www business standard com article mark...
# 7   https   www prnewswire com news releases titan...
# 8   https   www retail growth com news taneira by ...
# 9   https   newatlas com space titan atmosphere cy...
# 10  https   www cnbctv   com videos lifestyle norm...
# 11  https   www universetoday com        titans at...
# 12  https   www cbr com attack on titan season   f...
# 13  https   yourstory com         funding alert he...
# 14  https   www autoblog com            nissan tit...
# 15  https   www globenewswire com news release    ...
# 16  https   www uniindia com titan company launche...
# 17  https   www devdiscourse com article entertain...
# 18  https   www worldcement com europe cis        ...
# 19  https   www cbr com attack on titan chapter   ...
#
#                                                   img
# 0   data image gif base   R lGODlhAQABAIAAAP      ...
# 1   data image gif base   R lGODlhAQABAIAAAP      ...
# 2   data image gif base   R lGODlhAQABAIAAAP      ...
# 3   data image gif base   R lGODlhAQABAIAAAP      ...
# 4   data image gif base   R lGODlhAQABAIAAAP      ...
# 5   data image gif base   R lGODlhAQABAIAAAP      ...
# 6   data image gif base   R lGODlhAQABAIAAAP      ...
# 7   data image gif base   R lGODlhAQABAIAAAP      ...
# 8   data image gif base   R lGODlhAQABAIAAAP      ...
# 9   data image gif base   R lGODlhAQABAIAAAP      ...
# 10  data image gif base   R lGODlhAQABAIAAAP      ...
# 11  data image gif base   R lGODlhAQABAIAAAP      ...
# 12  data image gif base   R lGODlhAQABAIAAAP      ...
# 13  data image gif base   R lGODlhAQABAIAAAP      ...
# 14  data image gif base   R lGODlhAQABAIAAAP      ...
# 15  data image gif base   R lGODlhAQABAIAAAP      ...
# 16  data image gif base   R lGODlhAQABAIAAAP      ...
# 17  data image gif base   R lGODlhAQABAIAAAP      ...
# 18  data image gif base   R lGODlhAQABAIAAAP      ...
# 19  data image gif base   R lGODlhAQABAIAAAP      ...
#                                                 title                 media  \
# 0   titan comes up with business update for festiv...              Livemint
# 1   titan s jewellery business posts     growth in...        BloombergQuint
# 2   titan company share price hits    week high af...      Moneycontrol com
# 3   titan company gains as jewellery business reco...           NDTV Profit
# 4   rip  titan  pennsylvania police mourn k   offi...             USA TODAY
# 5   titan pharmaceuticals reports third quarter   ...            PRNewswire
# 6   titan  tbz  trading strategies for jewellery r...     Business Standard
# 7   titan international  inc  reports third quarte...            PRNewswire
# 8   taneira by titan launches its flagship store i...         retail growth
# 9   weird molecule found in titan s atmosphere hin...             New Atlas
# 10  normalcy returning  watches   eyewear business...              CNBCTV
# 11  titan   s atmosphere has all the ingredients f...        Universe Today
# 12  attack on titan    things we know about season...                   CBR
# 13   funding alert  healthtech startup prescribe r...         YourStory com
# 14  nissan reportedly tapping ev startup hercules ...              Autoblog
# 16  Kolkata  Nov     UNI  Titan Company announced ...
# 17  Attack on Titan Season    Final season likely ...
# 18  Sustainability  digitalisation and productivit...
# 19  In morbidly appropriate fashion for such a tum...
# 20  While it may be impossible to replace such a f...
# 21  The anime manga Attack On Titan has become a h...
# 22  Titan Company Ltd   incorporated in the year  ...
# 23  Titan Company Ltd   incorporated in the year  ...
# 24  Knowing Attack on Titan is one of the most wat...
# 25  With the commencement of our operations in Dub...
# 26  Attack On Titan    Characters Levi Should End ...
# 27  The Titan stock has bounced back to near Rs   ...
# 28  The sale features watch from brands like Fossi...
# 29  Earlier in the June quarter this year  Titan p...
#
#                                                  link  \
# 0   https   www livemint com market stock market n...
# 1   https   www bloombergquint com markets titans ...
# 2   https   www moneycontrol com news business sto...
# 3   https   www ndtv com business share market upd...
# 4   https   www usatoday com story news nation    ...
# 5   https   www prnewswire com news releases titan...
# 6   https   www business standard com article mark...
# 7   https   www prnewswire com news releases titan...
# 8   https   www retail growth com news taneira by ...
# 9   https   newatlas com space titan atmosphere cy...
# 10  https   www cnbctv   com videos lifestyle norm...
# 11  https   www universetoday com        titans at...
# 12  https   www cbr com attack on titan season   f...
# 13  https   yourstory com         funding alert he...
# 14  https   www autoblog com            nissan tit...
# 15  https   www globenewswire com news release    ...
# 16  https   www uniindia com titan company launche...
# 17  https   www devdiscourse com article entertain...
# 18  https   www worldcement com europe cis        ...
# 19  https   www cbr com attack on titan chapter   ...
# 20  https   www cbr com attack on titan anime watc...
# 21  https   screenrant com attack on titan about g...
# 22  https   economictimes indiatimes com markets s...
# 23  https   economictimes indiatimes com markets s...
# 24  https   micky com au attack on titan season   ...
# 25  https   www livemint com companies news titan ...
# 26  https   www cbr com attack on titan levi roman...
# 27  https   www cnbctv   com business bottomline t...
# 28  https   timesofindia indiatimes com most searc...
# 29  https   www business standard com article comp...
#
#                                                   img
# 0   data image gif base   R lGODlhAQABAIAAAP      ...
# 1   data image gif base   R lGODlhAQABAIAAAP      ...
# 2   data image gif base   R lGODlhAQABAIAAAP      ...
# 3   data image gif base   R lGODlhAQABAIAAAP      ...
# 4   data image gif base   R lGODlhAQABAIAAAP      ...
# 5   data image gif base   R lGODlhAQABAIAAAP      ...
# 6   data image gif base   R lGODlhAQABAIAAAP      ...
# 7   data image gif base   R lGODlhAQABAIAAAP      ...
# 8   data image gif base   R lGODlhAQABAIAAAP      ...
# 9   data image gif base   R lGODlhAQABAIAAAP      ...
# 10  data image gif base   R lGODlhAQABAIAAAP      ...
# 11  data image gif base   R lGODlhAQABAIAAAP      ...
# 12  data image gif base   R lGODlhAQABAIAAAP      ...
# 13  data image gif base   R lGODlhAQABAIAAAP      ...
# 14  data image gif base   R lGODlhAQABAIAAAP      ...
# 15  data image gif base   R lGODlhAQABAIAAAP      ...
# 16  data image gif base   R lGODlhAQABAIAAAP      ...
# 17  data image gif base   R lGODlhAQABAIAAAP      ...
# 18  data image gif base   R lGODlhAQABAIAAAP      ...
# 19  data image gif base   R lGODlhAQABAIAAAP      ...
# 20  data image gif base   R lGODlhAQABAIAAAP      ...
# 21  data image gif base   R lGODlhAQABAIAAAP      ...
# 22  data image gif base   R lGODlhAQABAIAAAP      ...
# 23  data image gif base   R lGODlhAQABAIAAAP      ...
# 24  data image gif base   R lGODlhAQABAIAAAP      ...
# 25  data image gif base   R lGODlhAQABAIAAAP      ...
# 26  data image gif base   R lGODlhAQABAIAAAP      ...
# 27  data image gif base   R lGODlhAQABAIAAAP      ...
# 28  data image gif base   R lGODlhAQABAIAAAP      ...
# 29  data image gif base   R lGODlhAQABAIAAAP      ...
#                                                 title  \
# 0   kane williamson and trent boult rested for wes...
# 1   new zealand s kane williamson and trent boult ...
# 2   nz   s kane williamson and trent boult to miss...
# 3   trent boult is now rocking with the guitar str...
# 4   trent boult   reverse swing is a string i want...
# 5   trent boult in awe of  world class  jasprit bu...
# 6   divers locate body of missing trent university...
# 7                trent alexander arnold injury update
# 8                 trent q  net loss at rs       crore
# 9   champions league  trent alexander arnold says ...
# 10        trent brown  rather unfortunate      season
# 11  raiders  trent brown is back on covid    reser...
# 12  raiders to lose draft pick over trent brown co...
# 13  trent brown again doesn t play  this time due ...
# 14  trent brown still in cleveland  undergoing tes...
# 15                   trent brown remains hospitalized
# 16     year old legally blind trent student brett ...
# 17  liverpool s trent alexander arnold says robert...
# 18  ipl       mumbai indians pacer trent boult sus...
# 19  reece james is a  better defender  than trent ...
#
#                       media         date                   datetime  \
# 0               India Today     week ago 2020-11-19 23:11:51.271912
# 1                Sky Sports     week ago 2020-11-19 23:11:51.273906
# 2        The Indian Express     week ago 2020-11-19 23:11:51.275901
# 3                    myKhel    weeks ago 2020-11-12 23:11:51.277895
# 4          ESPNcricinfo com     days ago 2020-11-24 23:11:51.279891
# 5          Cricket Addictor    weeks ago 2020-11-05 23:11:51.281885
# 6             Globalnews ca     days ago 2020-11-24 23:11:51.283879
# 7             ProSoccerTalk    weeks ago 2020-11-12 23:11:51.285875
# 8          Moneycontrol com    weeks ago 2020-11-05 23:11:51.287869
# 9                 Firstpost    weeks ago 2020-11-05 23:11:51.289863
# 10      Full Press Coverage    weeks ago 2020-11-05 23:11:54.756375
# 11         The Mercury News    weeks ago 2020-11-05 23:11:54.758369
# 12            Sporting News    weeks ago 2020-11-05 23:11:54.760367
# 13         The Boston Globe    weeks ago 2020-11-05 23:11:54.762325
# 14             Yahoo Sports    weeks ago 2020-11-05 23:11:54.764318
# 15         NBC Sports   NFL    weeks ago 2020-11-05 23:11:54.766313
# 16               PTBOCanada     days ago 2020-11-22 23:11:54.768343
# 17  Bavarian Football Works     week ago 2020-11-19 23:11:54.770337
# 18                India com    weeks ago 2020-11-05 23:11:54.773330
# 19               SPORTbible    weeks ago 2020-11-12 23:11:54.775324
#
#                                                  desc  \
# 0   Kane Williamson and Trent Boult rested for Wes...
# 1   Captain Kane Williamson and fast bowler Trent ...
# 2   NZ s Kane Williamson and Trent Boult to miss W...
# 3   Trent Boult is back home on quarantine after a...
# 4   Man of the Match in the recent IPL final  Tren...
# 5   It is fair to say that defending champions  Mu...
# 6   Police had been looking for Brett Michael Lebl...
# 7   Liverpool s lost another star to injury  this ...
# 8   The company had posted a net profit of Rs     ...
# 9   Champions League  Trent Alexander Arnold says ...
# 10  Also  Brown definitely did not ask to be place...
# 11  The Trent Brown saga took another twist Thursd...
# 12  Raiders to lose draft pick over Trent Brown CO...
# 13  Las Vegas Raiders tackle Trent Brown will rema...
# 14   Trent is still in Cleveland   Raiders coach J...
# 15  Trent Brown remains hospitalized  Posted by Mi...
# 16  On Friday  November   th  Brett Michael LeBlan...
# 17  Even Trent  like the rest of us  knows Lewando...
# 18  Trent Boult was breathing fire as in the first...
# 19  Former Liverpool man Johnson believes that the...
#
#                                                  link  \
# 0   https   www indiatoday in sports cricket story...
# 1   https   www skysports com cricket news        ...
# 2   https   indianexpress com article sports crick...
# 3   https   www mykhel com cricket trent boult is ...
# 4   https   www espncricinfo com story   id       ...
# 5   https   cricketaddictor com cricket trent boul...
# 6   https   globalnews ca news         divers loca...
# 7   https   soccer nbcsports com            trent ...
# 8   https   www moneycontrol com news business ear...
# 9   https   www firstpost com sports champions lea...
# 10  https   fullpresscoverage com            trent...
# 11  https   www mercurynews com            raiders...
# 12  https   www sportingnews com us nfl news raide...
# 13  https   www bostonglobe com            sports ...
# 14  https   sports yahoo com trent brown still cle...
# 15  https   profootballtalk nbcsports com         ...
# 16  https   www ptbocanada com journal            ...
# 17  https   www bavarianfootballworks com         ...
# 18  https   www india com sports cricket ipl      ...
# 19  https   www sportbible com football news reece...
#
#                                                   img
# 0   data image gif base   R lGODlhAQABAIAAAP      ...
# 1   data image gif base   R lGODlhAQABAIAAAP      ...
# 2   data image gif base   R lGODlhAQABAIAAAP      ...
# 3   data image gif base   R lGODlhAQABAIAAAP      ...
# 4   data image gif base   R lGODlhAQABAIAAAP      ...
# 5   data image gif base   R lGODlhAQABAIAAAP      ...
# 6   data image gif base   R lGODlhAQABAIAAAP      ...
# 7   data image gif base   R lGODlhAQABAIAAAP      ...
# 8   data image gif base   R lGODlhAQABAIAAAP      ...
# 9   data image gif base   R lGODlhAQABAIAAAP      ...
# 10  data image gif base   R lGODlhAQABAIAAAP      ...
# 11  data image gif base   R lGODlhAQABAIAAAP      ...
# 12  data image gif base   R lGODlhAQABAIAAAP      ...
# 13  data image gif base   R lGODlhAQABAIAAAP      ...
# 14  data image gif base   R lGODlhAQABAIAAAP      ...
# 15  data image gif base   R lGODlhAQABAIAAAP      ...
# 16  data image gif base   R lGODlhAQABAIAAAP      ...
# 17  data image gif base   R lGODlhAQABAIAAAP      ...
# 18  data image gif base   R lGODlhAQABAIAAAP      ...
# 19  data image gif base   R lGODlhAQABAIAAAP      ...
#                                                 title  \
# 0   kane williamson and trent boult rested for wes...
# 1   new zealand s kane williamson and trent boult ...
# 2   nz   s kane williamson and trent boult to miss...
# 3   trent boult is now rocking with the guitar str...
# 4   trent boult   reverse swing is a string i want...
# 5   trent boult in awe of  world class  jasprit bu...
# 6   divers locate body of missing trent university...
# 7                trent alexander arnold injury update
# 8                 trent q  net loss at rs       crore
# 3   Trent Boult is back home on quarantine after a...
# 4   Man of the Match in the recent IPL final  Tren...
# 5   It is fair to say that defending champions  Mu...
# 6   Police had been looking for Brett Michael Lebl...
# 7   Liverpool s lost another star to injury  this ...
# 8   The company had posted a net profit of Rs     ...
# 9   Champions League  Trent Alexander Arnold says ...
# 10  Also  Brown definitely did not ask to be place...
# 11  The Trent Brown saga took another twist Thursd...
# 12  Raiders to lose draft pick over Trent Brown CO...
# 13  Las Vegas Raiders tackle Trent Brown will rema...
# 14   Trent is still in Cleveland   Raiders coach J...
# 15  Trent Brown remains hospitalized  Posted by Mi...
# 16  On Friday  November   th  Brett Michael LeBlan...
# 17  Even Trent  like the rest of us  knows Lewando...
# 18  Trent Boult was breathing fire as in the first...
# 19  Former Liverpool man Johnson believes that the...
# 20  Trent University says an individual living off...
# 21  And Trent has found himself battling it out ag...
# 22  James Pattinson  centre  with Mumbai Indians t...
# 23  Stoke on Trent is expected to be placed in the...
# 24  Trent Ltd   incorporated in the year       is ...
# 25  In Stoke on Trent there have been an extra    ...
# 26  Trent  according to Bloomberg data  is trading...
# 27  Trent Limited  the  Company    today announced...
# 28  Watch Trent Reznor s Rock and Roll Hall of Fam...
# 29  New Delhi  Nov    PTI   Tata group retail firm...
#
#                                                  link  \
# 0   https   www indiatoday in sports cricket story...
# 1   https   www skysports com cricket news        ...
# 2   https   indianexpress com article sports crick...
# 3   https   www mykhel com cricket trent boult is ...
# 4   https   www espncricinfo com story   id       ...
# 5   https   cricketaddictor com cricket trent boul...
# 6   https   globalnews ca news         divers loca...
# 7   https   soccer nbcsports com            trent ...
# 8   https   www moneycontrol com news business ear...
# 9   https   www firstpost com sports champions lea...
# 10  https   fullpresscoverage com            trent...
# 11  https   www mercurynews com            raiders...
# 12  https   www sportingnews com us nfl news raide...
# 13  https   www bostonglobe com            sports ...
# 14  https   sports yahoo com trent brown still cle...
# 15  https   profootballtalk nbcsports com         ...
# 16  https   www ptbocanada com journal            ...
# 17  https   www bavarianfootballworks com         ...
# 18  https   www india com sports cricket ipl      ...
# 19  https   www sportbible com football news reece...
# 20  https   globalnews ca news         covid    tr...
# 21  https   www sportbible com football news trent...
# 22  https   www indiatvnews com sports cricket jas...
# 23  https   www stokesentinel co uk news stoke on ...
# 24  https   economictimes indiatimes com markets s...
# 25  https   www stokesentinel co uk news stoke on ...
# 26  https   www bloombergquint com markets trent s...
# 27  https   www equitybulls com admin news     new...
# 28  https   www rollingstone com music music news ...
# 29  https   www outlookindia com newsscroll trent ...
#
#                                                   img
# 0   data image gif base   R lGODlhAQABAIAAAP      ...
# 1   data image gif base   R lGODlhAQABAIAAAP      ...
# 2   data image gif base   R lGODlhAQABAIAAAP      ...
# 3   data image gif base   R lGODlhAQABAIAAAP      ...
# 4   data image gif base   R lGODlhAQABAIAAAP      ...
# 5   data image gif base   R lGODlhAQABAIAAAP      ...
# 6   data image gif base   R lGODlhAQABAIAAAP      ...
# 7   data image gif base   R lGODlhAQABAIAAAP      ...
# 8   data image gif base   R lGODlhAQABAIAAAP      ...
# 9   data image gif base   R lGODlhAQABAIAAAP      ...
# 10  data image gif base   R lGODlhAQABAIAAAP      ...
# 11  data image gif base   R lGODlhAQABAIAAAP      ...
# 12  data image gif base   R lGODlhAQABAIAAAP      ...
# 13  data image gif base   R lGODlhAQABAIAAAP      ...
# 14  data image gif base   R lGODlhAQABAIAAAP      ...
# 15  data image gif base   R lGODlhAQABAIAAAP      ...
# 16  data image gif base   R lGODlhAQABAIAAAP      ...
# 17  data image gif base   R lGODlhAQABAIAAAP      ...
# 18  data image gif base   R lGODlhAQABAIAAAP      ...
# 19  data image gif base   R lGODlhAQABAIAAAP      ...
# 20  data image gif base   R lGODlhAQABAIAAAP      ...
# 21  data image gif base   R lGODlhAQABAIAAAP      ...
# 22  data image gif base   R lGODlhAQABAIAAAP      ...
# 23  data image gif base   R lGODlhAQABAIAAAP      ...
# 24  data image gif base   R lGODlhAQABAIAAAP      ...
# 25  data image gif base   R lGODlhAQABAIAAAP      ...
# 26  data image gif base   R lGODlhAQABAIAAAP      ...
# 27  data image gif base   R lGODlhAQABAIAAAP      ...
# 28  data image gif base   R lGODlhAQABAIAAAP      ...
# 29  data image gif base   R lGODlhAQABAIAAAP      ...
#                                                 title              media  \
# 0   adani green energy q  results  profit plunges ...     Economic Times
# 1   adani green energy profit plunges over     to ...  Business Standard
# 2   stocks to watch  adani gas  adani ports  indus...           Livemint
# 3   market movers  adani enterprises  adani green ...     Economic Times
# 4   adani green hits fresh all time high  zooms   ...  Business Standard
# 5   adani green energy arm commissions    mw solar...  pv magazine India
# 6   stock market update  midcap stocks drop  adani...     Economic Times
# 7   adani green energy  laurus labs among top valu...  Business Standard
# 8   trade spotlight  indiabulls housing  aurobindo...   Moneycontrol com
# 9   the week that was  adani green  ge power among...     Economic Times
# 10  stock market update  bse capital goods index g...     Economic Times
# 11  acc  adani green among    stocks to be added i...   Moneycontrol com
# 12  trent gains      yes bank up    on msci india ...  Business Standard
# 13      msci adds    stocks to india index  drops two           Livemint
# 14  adani green  adani ports  trading strategies f...  Business Standard
# 15  adani green energy profit plunges over     to ...   Moneycontrol com
# 16  adani green share price falls    after vistra ...   Moneycontrol com
# 17  tata motors a trading bet  keep out of adani g...     Economic Times
# 18  stocks to watch  adani green  adani power  hpc...     BloombergQuint
# 19  stocks in the news   lakshmi vilas bank  futur...   Moneycontrol com
#
#             date                   datetime  \
# 0      weeks ago 2020-11-05 23:12:05.181068
# 1      weeks ago 2020-11-05 23:12:05.184099
# 2      weeks ago 2020-11-05 23:12:05.186093
# 3      weeks ago 2020-11-12 23:12:05.188092
# 4      weeks ago 2020-11-12 23:12:05.190083
# 5      weeks ago 2020-11-05 23:12:05.192076
# 6        day ago 2020-11-25 23:12:05.194073
# 7      weeks ago 2020-11-12 23:12:05.196032
# 8      weeks ago 2020-11-12 23:12:05.198061
# 9      weeks ago 2020-11-05 23:12:05.200056
# 10      week ago 2020-11-19 23:12:07.306457
# 11     weeks ago 2020-11-12 23:12:07.308452
# 12     weeks ago 2020-11-12 23:12:07.310447
# 13     weeks ago 2020-11-12 23:12:07.313439
# 14      days ago 2020-11-24 23:12:07.315434
# 15     weeks ago 2020-11-05 23:12:07.317429
# 16     hours ago 2020-11-26 10:12:07.319466
# 17      week ago 2020-11-19 23:12:07.321461
# 18     weeks ago 2020-11-05 23:12:07.323455
# 19     hours ago 2020-11-26 09:12:07.325450
#
#                                                  desc  \
# 0   Adani Green Energy Q  Results  Profit plunges ...
# 1   Adani Green Energy profit plunges over     to ...
# 2   Earnings  Adani Enterprises  Adani Green Energ...
# 3   Market Movers  Adani Enterprises  Adani Green ...
# 4   Shares of Adani Green Energy  AGEL  were locke...
# 5   The latest addition takes Adani Green Energy s...
# 6   Shares of Larsen   Toubro Infotech  down      ...
# 7   Adani Green Energy has rallied almost       pe...
# 8   Trade Spotlight  Indiabulls Housing  Aurobindo...
# 9   Adani Green  Adani Enterprises and Adani Gas  ...
# 10  Shares of Adani Green  up      per cent   Kalp...
# 11  Indian stocks that will become part of the MSC...
# 12  Shares of Adani Green Energy  Trent  YES Bank ...
# 13  The    stocks added are Kotak Mahindra Bank  Y...
# 14  Most Adani Group stocks were trading in the gr...
# 15  The consolidated net profit of the company was...
# 16  Adani Green share price falls    after Vistra ...
# 17  I am a little sceptical of the vertical moves ...
# 18  Adani Green Energy Q   Consolidated  YoY   Rev...
# 19  Stocks in the news   Lakshmi Vilas Bank  Futur...
#
#                                                  link  \
# 0   https   economictimes indiatimes com markets s...
# 1   https   www business standard com article comp...
# 2   https   www livemint com market stock market n...
# 3   https   economictimes indiatimes com markets s...
# 4   https   www business standard com article mark...
# 5   https   www pv magazine india com            a...
# 6   https   economictimes indiatimes com markets s...
# 7   https   www business standard com article mark...
# 8   https   www moneycontrol com news business mar...
# 9   https   economictimes indiatimes com markets s...
# 10  https   economictimes indiatimes com markets s...
# 11  https   www moneycontrol com news business mar...
# 12  https   www business standard com article mark...
# 13  https   www livemint com market stock market n...
# 14  https   www business standard com article mark...
# 15  https   www moneycontrol com news business ear...
# 16  https   www moneycontrol com news business sto...
# 17  https   economictimes indiatimes com markets e...
# 18  https   www bloombergquint com business stocks...
# 19  https   www moneycontrol com news photos busin...
#
#                                                   img
# 0   data image gif base   R lGODlhAQABAIAAAP      ...
# 1   data image gif base   R lGODlhAQABAIAAAP      ...
# 2   data image gif base   R lGODlhAQABAIAAAP      ...
# 3   data image gif base   R lGODlhAQABAIAAAP      ...
# 4   data image gif base   R lGODlhAQABAIAAAP      ...
# 5   data image gif base   R lGODlhAQABAIAAAP      ...
# 6   data image gif base   R lGODlhAQABAIAAAP      ...
# 7   data image gif base   R lGODlhAQABAIAAAP      ...
# 8   data image gif base   R lGODlhAQABAIAAAP      ...
# 9   data image gif base   R lGODlhAQABAIAAAP      ...
# 10  data image gif base   R lGODlhAQABAIAAAP      ...
# 11  data image gif base   R lGODlhAQABAIAAAP      ...
# 12  data image gif base   R lGODlhAQABAIAAAP      ...
# 13  data image gif base   R lGODlhAQABAIAAAP      ...
# 26  https   www business standard com article news...
# 27  https   www moneycontrol com news business ear...
# 28  https   www business standard com article news...
# 29  https   www dsij in DSIJArticleDetail ArtMID  ...
#
#                                                   img
# 0   data image gif base   R lGODlhAQABAIAAAP      ...
# 1   data image gif base   R lGODlhAQABAIAAAP      ...
# 2   data image gif base   R lGODlhAQABAIAAAP      ...
# 3   data image gif base   R lGODlhAQABAIAAAP      ...
# 4   data image gif base   R lGODlhAQABAIAAAP      ...
# 5   data image gif base   R lGODlhAQABAIAAAP      ...
# 6   data image gif base   R lGODlhAQABAIAAAP      ...
# 7   data image gif base   R lGODlhAQABAIAAAP      ...
# 8   data image gif base   R lGODlhAQABAIAAAP      ...
# 9   data image gif base   R lGODlhAQABAIAAAP      ...
# 10  data image gif base   R lGODlhAQABAIAAAP      ...
# 11  data image gif base   R lGODlhAQABAIAAAP      ...
# 12  data image gif base   R lGODlhAQABAIAAAP      ...
# 13  data image gif base   R lGODlhAQABAIAAAP      ...
# 14  data image gif base   R lGODlhAQABAIAAAP      ...
# 15  data image gif base   R lGODlhAQABAIAAAP      ...
# 16  data image gif base   R lGODlhAQABAIAAAP      ...
# 17  data image gif base   R lGODlhAQABAIAAAP      ...
# 18  data image gif base   R lGODlhAQABAIAAAP      ...
# 19  data image gif base   R lGODlhAQABAIAAAP      ...
# 20  data image gif base   R lGODlhAQABAIAAAP      ...
# 21  data image gif base   R lGODlhAQABAIAAAP      ...
# 22  data image gif base   R lGODlhAQABAIAAAP      ...
# 23  data image gif base   R lGODlhAQABAIAAAP      ...
# 24  data image gif base   R lGODlhAQABAIAAAP      ...
# 25  data image gif base   R lGODlhAQABAIAAAP      ...
# 26  data image gif base   R lGODlhAQABAIAAAP      ...
# 27  data image gif base   R lGODlhAQABAIAAAP      ...
# 28  data image gif base   R lGODlhAQABAIAAAP      ...
# 29  data image gif base   R lGODlhAQABAIAAAP      ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-ac1102c46379> in <module>
#      15
#      16         df.replace("[^a-zA-Z]"," ",regex=True, inplace=True)
# ---> 17         df['title'] = df['title'].str.lower()
#      18         headline.append(' '.join(str(x) for x in df['title']))
#      19         #list1= [i for i in range(7)]
#
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\envs\tensor\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'title'

# %%
headline
# Out:
# ['titan comes up with business update for festive season  shares near    week high titan s jewellery business posts     growth in festive season titan company share price hits    week high after festive cheer boosts business titan company gains as jewellery business records growth in festive season rip  titan  pennsylvania police mourn k   officer that  died honorably  during a burglary search titan pharmaceuticals reports third quarter      financial     titan  tbz  trading strategies for jewellery related stocks on dhanteras titan international  inc  reports third quarter      results taneira by titan launches its flagship store in mumbai weird molecule found in titan s atmosphere hints at complex     normalcy returning  watches   eyewear business catching up  titan titan   s atmosphere has all the ingredients for life  but not life as we know it attack on titan    things we know about season        questions we still have   funding alert  healthtech startup prescribe raises rs   cr from titan capital  others nissan reportedly tapping ev startup hercules to electrify titan pickup linq   titan school solutions announce merger titan company launches first international tanishq boutique attack on titan season    final season likely to split in two parts  what more we know titan cement group and flsmidth announce new strategic partnership agreement attack on titan s final battle begins amid global devastation',
en johnson covid     single cases confirmed at trent university and fleming college in peterborough trent alexander arnold reveals what it s like to come up against adama traore s frightening speed ipl       jasprit bumrah and trent boult have been standout performers for mi  says james pattinson stoke on trent set to be plunged into toughest tier when second lockdown end neutral on trent  target price rs      motilal oswal another     coronavirus cases in stoke on trent and staffordshire trent stock posts biggest one day gain in five months on msci inclusion trent ltd announces q  fy   results watch trent reznor s rock and roll hall of fame induction speech for nine inch nails trent q  net loss at rs       cr',
#  'adani green energy q  results  profit plunges over     to rs       crore adani green energy profit plunges over     to rs       cr in sept quarter stocks to watch  adani gas  adani ports  indusind bank  pvr  bank of baroda market movers  adani enterprises  adani green hit fresh    week high     stocks flash sell signal adani green hits fresh all time high  zooms      in samvat      adani green energy arm commissions    mw solar project stock market update  midcap stocks drop  adani green loses    adani green energy  laurus labs among top value creators in samvat      trade spotlight  indiabulls housing  aurobindo pharma  adani green in focus the week that was  adani green  ge power among    stocks that buzzed most stock market update  bse capital goods index gains over     adani green jumps    acc  adani green among    stocks to be added in msci global index trent gains      yes bank up    on msci india index inclusion from december msci adds    stocks to india index  drops two adani green  adani ports  trading strategies for adani group stocks adani green energy profit plunges over     to rs       crore in september quarter adani green share price falls    after vistra itcl offloads      crore shares tata motors a trading bet  keep out of adani green stocks to watch  adani green  adani power  hpcl  inox leisure  united spirits stocks in the news   lakshmi vilas bank  future consumer  adani green energy  hfcl  laurus labs',
#  'adani green energy q  results  profit plunges over     to rs       crore adani green energy profit plunges over     to rs       cr in sept quarter stocks to watch  adani gas  adani ports  indusind bank  pvr  bank of baroda market movers  adani enterprises  adani green hit fresh    week high     stocks flash sell signal adani green hits fresh all time high  zooms      in samvat      adani green energy arm commissions    mw solar project stock market update  midcap stocks drop  adani green loses    adani green energy  laurus labs among top value creators in samvat      trade spotlight  indiabulls housing  aurobindo pharma  adani green in focus the week that was  adani green  ge power among    stocks that buzzed most stock market update  bse capital goods index gains over     adani green jumps    acc  adani green among    stocks to be added in msci global index trent gains      yes bank up    on msci india index inclusion from december msci adds    stocks to india index  drops two adani green  adani ports  trading strategies for adani group stocks adani green energy profit plunges over     to rs       crore in september quarter adani green share price falls    after vistra itcl offloads      crore shares tata motors a trading bet  keep out of adani green stocks to watch  adani green  adani power  hpcl  inox leisure  united spirits stocks in the news   lakshmi vilas bank  future consumer  adani green energy  hfcl  laurus labs adani green energy has no guaranteed buyer for    billion solar project  report adani green energy share hits all time high  nears rs       mark adani green energy ltd gains for fifth session what   s the story  adani green energy upper circuit stocks  adani green jumps   per cent  cg power     adani green energy announces commissioning of    mw solar power project adani green energy ltd slips    adani green ene standalone september      net sales at rs       crore  down        y o y adani green energy ltd surges        s p bse power index gains       buzzing stocks  adani green locks in at lower circuit    ']

# %%
len(headline)
# Out:
# 6

# %%
import pickle

with open('stock_senti_analysis_final_vectorizer.pkl', 'rb') as f:
    vectorizer = pickle.load(f)

# %%
with open('stock_senti_analysis_final_model.pkl', 'rb') as fr:
    model = pickle.load(fr)

# %%
test_df = vectorizer.transform(headline)

# %%
model.predict(test_df)
# Out:
# array([1, 1, 1, 1, 1, 1], dtype=int64)

# %%
import yfinance as yf

# %%
ytickers = []

for i in sort_orders[:6]:
    ytickers.append(i[0])

# %%
import tensorflow as tf
print("Tensorflow ver: " + tf.__version__)
# Out:
# Tensorflow ver: 2.1.0

# %%
# Import modules and packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Import Libraries and packages from Keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam

# %%
# ---> Special function: convert <datetime.date> to <Timestamp>
def datetime_to_timestamp(x):
    '''
        x : a given datetime value (datetime.date)
    '''
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')

# %%
DF_pred=[]
for tick in ytickers:
    
    ms = yf.Ticker(tick)

    dataset_train = ms.history(start="2017-01-01", end="2020-11-01")
    dataset_train.drop(['Dividends', 'Stock Splits'], axis=1)
    dataset_train.reset_index(inplace=True)
    
    cols = list(dataset_train)[1:6]
    
    #%%time
    # Extract dates (will be used in visualization)
    datelist_train = list(dataset_train['Date'])
    #datelist_train = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in datelist_train]
    
    dataset_train = dataset_train[cols].astype(str)
    for i in cols:
        for j in range(0, len(dataset_train)):
            dataset_train[i][j] = dataset_train[i][j].replace(',', '')

    dataset_train = dataset_train.astype(float)

    # Using multiple features (predictors)
    training_set = dataset_train.to_numpy()
    
    # Feature Scaling
    sc = StandardScaler()
    training_set_scaled = sc.fit_transform(training_set)

    sc_predict = StandardScaler()
    sc_predict.fit_transform(training_set[:, 0:1])

    # Creating a data structure with 90 timestamps and 1 output
    X_train = []
    y_train = []

    n_future = 30   # Number of days we want top predict into the future
    n_past = 90    # Number of past days we want to use to predict the future

    for i in range(n_past, len(training_set_scaled) - n_future +1):
        X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
        y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

    X_train, y_train = np.array(X_train), np.array(y_train)
    # Initializing the Neural Network based on LSTM
    model = Sequential()

    # Adding 1st LSTM layer
    model.add(LSTM(units=64, return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

    # Adding 2nd LSTM layer
    model.add(LSTM(units=10, return_sequences=False))

    # Adding Dropout
    model.add(Dropout(0.25))

    # Output layer
    model.add(Dense(units=1, activation='linear'))

    # Compiling the Neural Network
    model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')
    
    #%%time
    es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
    rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
    mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

    tb = TensorBoard('logs')

    history = model.fit(X_train, y_train, shuffle=True, epochs=30, callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
    # Generate list of sequence of days for predictions
    datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

    '''
    Remeber, we have datelist_train from begining.
    '''

    # Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
    datelist_future_ = []
    for this_timestamp in datelist_future:
        datelist_future_.append(this_timestamp.date())
        
    # Perform predictions
    predictions_future = model.predict(X_train[-n_future:])

    predictions_train = model.predict(X_train[n_past:])
    
    # Inverse the predictions to original measurements

    

    y_pred_future = sc_predict.inverse_transform(predictions_future)
    y_pred_train = sc_predict.inverse_transform(predictions_train)

    PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Open']).set_index(pd.Series(datelist_future))
    PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['Open']).set_index(pd.Series(datelist_train[2 * n_past + n_future -1:]))
    # Convert <datetime.date> to <Timestamp> for PREDCITION_TRAIN
    PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

    #PREDICTION_TRAIN.head(3)
    
    
    
    DF_pred.append(PREDICTION_TRAIN)
# Out:
# Train on 660 samples, validate on 166 samples
# Epoch 1/30
# 512/660 [======================>.......] - ETA: 1s - loss: 0.7773
# Epoch 00001: val_loss improved from inf to 0.44031, saving model to weights.h5
# 660/660 [==============================] - 7s 11ms/sample - loss: 0.6496 - val_loss: 0.4403
# Epoch 2/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2555
# Epoch 00002: val_loss improved from 0.44031 to 0.27722, saving model to weights.h5
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2386 - val_loss: 0.2772
# Epoch 3/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1766
# Epoch 00003: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1662 - val_loss: 0.2939
# Epoch 4/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1414
# Epoch 00004: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1373 - val_loss: 0.3654
# Epoch 5/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1351
# Epoch 00005: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 1ms/sample - loss: 0.1300 - val_loss: 0.3681
# Epoch 6/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1137
# Epoch 00006: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1116 - val_loss: 0.3783
# Epoch 7/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1102
# Epoch 00007: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 1ms/sample - loss: 0.1113 - val_loss: 0.4544
# Epoch 8/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1094
# Epoch 00008: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1126 - val_loss: 0.5125
# Epoch 9/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1027
# Epoch 00009: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1101 - val_loss: 0.4520
# Epoch 10/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1053
# Epoch 00010: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1098 - val_loss: 0.4604
# Epoch 11/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1097
# Epoch 00011: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 1ms/sample - loss: 0.1074 - val_loss: 0.3974
# Epoch 12/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0964
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00012: val_loss did not improve from 0.27722
# 660/660 [==============================] - 1s 1ms/sample - loss: 0.0972 - val_loss: 0.4451
# Epoch 00012: early stopping
# Train on 660 samples, validate on 166 samples
# Epoch 1/30
# 512/660 [======================>.......] - ETA: 1s - loss: 0.4585
# Epoch 00001: val_loss improved from inf to 0.57065, saving model to weights.h5
# 660/660 [==============================] - 8s 12ms/sample - loss: 0.3833 - val_loss: 0.5707
# Epoch 2/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1635
# Epoch 00002: val_loss did not improve from 0.57065
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1526 - val_loss: 0.6666
# Epoch 3/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1232
# Epoch 00003: val_loss did not improve from 0.57065
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1249 - val_loss: 0.6252
# Epoch 4/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1057
# Epoch 00004: val_loss did not improve from 0.57065
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.1104 - val_loss: 0.6152
# Epoch 5/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0891
# Epoch 00005: val_loss did not improve from 0.57065
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1034 - val_loss: 0.7332
# Epoch 6/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1011
# Epoch 00006: val_loss did not improve from 0.57065
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.1168 - val_loss: 0.5770
# Epoch 7/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0961
# Epoch 00007: val_loss did not improve from 0.57065
# 660/660 [==============================] - 3s 5ms/sample - loss: 0.1061 - val_loss: 0.5987
# Epoch 8/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0987
# Epoch 00008: val_loss did not improve from 0.57065
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0986 - val_loss: 0.6547
# Epoch 9/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0996
# Epoch 00009: val_loss did not improve from 0.57065
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.0928 - val_loss: 0.6796
# Epoch 10/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0899
# Epoch 00010: val_loss did not improve from 0.57065
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.1036 - val_loss: 0.6816
# Epoch 11/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0836
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00011: val_loss did not improve from 0.57065
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.0870 - val_loss: 0.7968
# Epoch 00011: early stopping
# Train on 371 samples, validate on 93 samples
# Epoch 1/30
# 256/371 [===================>..........] - ETA: 1s - loss: 0.2735
# Epoch 00001: val_loss improved from inf to 2.10952, saving model to weights.h5
# 371/371 [==============================] - 6s 18ms/sample - loss: 0.3713 - val_loss: 2.1095
# Epoch 2/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.1483
# Epoch 00002: val_loss did not improve from 2.10952
# 371/371 [==============================] - 1s 3ms/sample - loss: 0.1554 - val_loss: 2.2988
# Epoch 3/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.1701
# Epoch 00003: val_loss improved from 2.10952 to 1.70456, saving model to weights.h5
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.1601 - val_loss: 1.7046
# Epoch 4/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0931
# Epoch 00004: val_loss improved from 1.70456 to 1.52681, saving model to weights.h5
# 371/371 [==============================] - 1s 3ms/sample - loss: 0.1011 - val_loss: 1.5268
# Epoch 5/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0835
# Epoch 00005: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0867 - val_loss: 1.6916
# Epoch 6/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0787
# Epoch 00006: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0805 - val_loss: 2.0769
# Epoch 7/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0834
# Epoch 00007: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0733 - val_loss: 2.2564
# Epoch 8/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0649
# Epoch 00008: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0670 - val_loss: 2.8089
# Epoch 9/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0620
# Epoch 00009: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0582 - val_loss: 3.5229
# Epoch 10/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0693
# Epoch 00010: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0584 - val_loss: 3.8965
# Epoch 11/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0659
# Epoch 00011: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0576 - val_loss: 4.4761
# Epoch 12/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0536
# Epoch 00012: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0587 - val_loss: 4.9162
# Epoch 13/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0633
# Epoch 00013: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0554 - val_loss: 5.0005
# Epoch 14/30
# 256/371 [===================>..........] - ETA: 0s - loss: 0.0520
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00014: val_loss did not improve from 1.52681
# 371/371 [==============================] - 1s 2ms/sample - loss: 0.0527 - val_loss: 5.1757
# Epoch 00014: early stopping
# Train on 660 samples, validate on 166 samples
# Epoch 1/30
# 256/660 [==========>...................] - ETA: 6s - loss: 0.8160WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.623131). Check your callbacks.
# 512/660 [======================>.......] - ETA: 1s - loss: 0.6158
# Epoch 00001: val_loss improved from inf to 0.59017, saving model to weights.h5
# 660/660 [==============================] - 7s 11ms/sample - loss: 0.5475 - val_loss: 0.5902
# Epoch 2/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2807
# Epoch 00002: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2671 - val_loss: 1.0477
# Epoch 3/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2271
# Epoch 00003: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2250 - val_loss: 1.1510
# Epoch 4/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2535
# Epoch 00004: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2465 - val_loss: 1.1318
# Epoch 5/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2273
# Epoch 00005: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2323 - val_loss: 1.0345
# Epoch 6/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2137
# Epoch 00006: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2106 - val_loss: 0.8847
# Epoch 7/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2234
# Epoch 00007: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2205 - val_loss: 1.1343
# Epoch 8/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2049
# Epoch 00008: val_loss did not improve from 0.59017
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.2012 - val_loss: 1.0386
# Epoch 9/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1743
# Epoch 00009: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1795 - val_loss: 0.9443
# Epoch 10/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2028
# Epoch 00010: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2126 - val_loss: 0.9538
# Epoch 11/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.2121
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00011: val_loss did not improve from 0.59017
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.2088 - val_loss: 1.2006
# Epoch 00011: early stopping
# Train on 660 samples, validate on 166 samples
# Epoch 1/30
# 512/660 [======================>.......] - ETA: 1s - loss: 0.3041
# Epoch 00001: val_loss improved from inf to 0.26740, saving model to weights.h5
# 660/660 [==============================] - 7s 11ms/sample - loss: 0.2716 - val_loss: 0.2674
# Epoch 2/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1384
# Epoch 00002: val_loss improved from 0.26740 to 0.16289, saving model to weights.h5
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.1247 - val_loss: 0.1629
# Epoch 3/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0912
# Epoch 00003: val_loss did not improve from 0.16289
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.0864 - val_loss: 0.2269
# Epoch 4/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0703
# Epoch 00004: val_loss did not improve from 0.16289
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.0703 - val_loss: 0.2573
# Epoch 5/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0847
# Epoch 00005: val_loss did not improve from 0.16289
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0858 - val_loss: 0.1857
# Epoch 6/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0850
# Epoch 00006: val_loss did not improve from 0.16289
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0802 - val_loss: 0.1951
# Epoch 7/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0682
# Epoch 00007: val_loss did not improve from 0.16289
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0710 - val_loss: 0.2319
# Epoch 8/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0716
# Epoch 00008: val_loss did not improve from 0.16289
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0715 - val_loss: 0.1638
# Epoch 9/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0648
# Epoch 00009: val_loss improved from 0.16289 to 0.14395, saving model to weights.h5
# 660/660 [==============================] - 2s 4ms/sample - loss: 0.0634 - val_loss: 0.1440
# Epoch 10/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0698
# Epoch 00010: val_loss did not improve from 0.14395
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0681 - val_loss: 0.2051
# Epoch 11/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0648
# Epoch 00011: val_loss did not improve from 0.14395
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0632 - val_loss: 0.1996
# Epoch 12/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0646
# Epoch 00012: val_loss did not improve from 0.14395
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0668 - val_loss: 0.1460
# Epoch 13/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0664
# Epoch 00013: val_loss did not improve from 0.14395
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0688 - val_loss: 0.1615
# Epoch 14/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0603
# Epoch 00014: val_loss did not improve from 0.14395
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0614 - val_loss: 0.1817
# Epoch 15/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0671
# Epoch 00015: val_loss did not improve from 0.14395
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0672 - val_loss: 0.1591
# Epoch 16/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0661
# Epoch 00016: val_loss improved from 0.14395 to 0.12872, saving model to weights.h5
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0648 - val_loss: 0.1287
# Epoch 17/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0670
# Epoch 00017: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0643 - val_loss: 0.1555
# Epoch 18/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0669
# Epoch 00018: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0657 - val_loss: 0.1484
# Epoch 19/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0723
# Epoch 00019: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0716 - val_loss: 0.1408
# Epoch 20/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0657
# Epoch 00020: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0660 - val_loss: 0.1429
# Epoch 21/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0622
# Epoch 00021: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0646 - val_loss: 0.1372
# Epoch 22/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0704
# Epoch 00022: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0704 - val_loss: 0.1321
# Epoch 23/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0667
# Epoch 00023: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0647 - val_loss: 0.1555
# Epoch 24/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0591
# Epoch 00024: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0605 - val_loss: 0.1315
# Epoch 25/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0603
# Epoch 00025: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0597 - val_loss: 0.1547
# Epoch 26/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0592
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00026: val_loss did not improve from 0.12872
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0608 - val_loss: 0.1310
# Epoch 00026: early stopping
# Train on 660 samples, validate on 166 samples
# Epoch 1/30
# 512/660 [======================>.......] - ETA: 1s - loss: 0.6258
# Epoch 00001: val_loss improved from inf to 0.04836, saving model to weights.h5
# 660/660 [==============================] - 7s 11ms/sample - loss: 0.5185 - val_loss: 0.0484
# Epoch 2/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1389
# Epoch 00002: val_loss did not improve from 0.04836
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.1363 - val_loss: 0.0675
# Epoch 3/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1301
# Epoch 00003: val_loss improved from 0.04836 to 0.03312, saving model to weights.h5
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.1270 - val_loss: 0.0331
# Epoch 4/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1112
# Epoch 00004: val_loss improved from 0.03312 to 0.02110, saving model to weights.h5
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.1124 - val_loss: 0.0211
# Epoch 5/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.1083
# Epoch 00005: val_loss improved from 0.02110 to 0.01363, saving model to weights.h5
# 660/660 [==============================] - 3s 4ms/sample - loss: 0.1054 - val_loss: 0.0136
# Epoch 6/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0941
# Epoch 00006: val_loss did not improve from 0.01363
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.0916 - val_loss: 0.0149
# Epoch 7/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0912
# Epoch 00007: val_loss did not improve from 0.01363
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.0915 - val_loss: 0.0150
# Epoch 8/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0881
# Epoch 00008: val_loss did not improve from 0.01363
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.0903 - val_loss: 0.0190
# Epoch 9/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0836
# Epoch 00009: val_loss improved from 0.01363 to 0.01348, saving model to weights.h5
# 660/660 [==============================] - 3s 4ms/sample - loss: 0.0831 - val_loss: 0.0135
# Epoch 10/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0846
# Epoch 00010: val_loss did not improve from 0.01348
# 660/660 [==============================] - 2s 3ms/sample - loss: 0.0875 - val_loss: 0.0235
# Epoch 11/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0860
# Epoch 00011: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0841 - val_loss: 0.0135
# Epoch 12/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0939
# Epoch 00012: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0930 - val_loss: 0.0189
# Epoch 13/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0833
# Epoch 00013: val_loss did not improve from 0.01348
# 660/660 [==============================] - 2s 2ms/sample - loss: 0.0846 - val_loss: 0.0159
# Epoch 14/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0872
# Epoch 00014: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0881 - val_loss: 0.0141
# Epoch 15/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0893
# Epoch 00015: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0877 - val_loss: 0.0291
# Epoch 16/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0803
# Epoch 00016: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0778 - val_loss: 0.0165
# Epoch 17/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0836
# Epoch 00017: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0830 - val_loss: 0.0202
# Epoch 18/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0845
# Epoch 00018: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0840 - val_loss: 0.0153
# Epoch 19/30
# 512/660 [======================>.......] - ETA: 0s - loss: 0.0841
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00019: val_loss did not improve from 0.01348
# 660/660 [==============================] - 1s 2ms/sample - loss: 0.0818 - val_loss: 0.0166
# Epoch 00019: early stopping

# %%
DF_pred[0]
# Out:
#                    Open
# 2017-11-06   745.254944
# 2017-11-07   741.161499
# 2017-11-08   734.865356
# 2017-11-09   728.504456
# 2017-11-10   722.595398
# ...                 ...
# 2020-10-26  1196.003540
# 2020-10-27  1193.972290
# 2020-10-28  1191.453247
# 2020-10-29  1189.341187
# 2020-10-30  1187.422119
#
# [736 rows x 1 columns]
